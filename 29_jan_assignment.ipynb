# %%
##1
python was developed by Guido van Rossum.

##2
python is interpreted, interactive , object oriented programming language.

##3
yes it is case sensitive.

##4
extension --> .py

##5
python is an interpreted language.

##6
blocks code of python are -->a module , a function body and a class defination.

##7
character for single line comments --> #.

##8
function to find currnt version --> sys.version.

##9
the anonymous function during run time --> lambda.

##10
pip --> preffered installer program (package manager for python packages or modules).

##11
built in fucntion --> dict(),len(),print(),set(),type(),float().

##12
maximum length of identifiers--> 79 characters.

##13
benefits of python---> 1.Eas to learn and use
                       2.Open source
                       3.Massive libraries
                       4.Portable.
            
##14
memory is managed b y creating heap containing all python objects and data structures.

##15
download by --> python.org
set path by -->1. Right-clicking This PC and going to Properties.

               2.Clicking on the Advanced system settings in the menu on the left.

               3.Clicking on the Environment Variables button o​n the bottom right.
               
               4.In the System variables section, selecting the Path variable and 
                clicking on Edit. The next screen will show all the directories
                that are currently a part of the PATH variable.

                5.Clicking on New and entering Python’s install directory.
                
##16
yes intendtion is required in python.
